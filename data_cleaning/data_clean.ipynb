# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
music_data_df = pd.read_csv(
    Path("Data/data.csv")
)

# %%
music_data_df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# ...

# %%
ten_df=music_data_df.loc[(music_data_df['year']>=2010) & (music_data_df['year']<=2020)]
ten_df
# Out:
#         acousticness                             artists  danceability  \
# 7054        0.022200                     ['Tame Impala']         0.450
# 7055        0.000103            ['Bring Me The Horizon']         0.382
# 7056        0.852000                       ['Daft Punk']         0.179
# 7057        0.080900                         ['TobyMac']         0.507
# 7058        0.002960                   ['Kenny Chesney']         0.315
# ...              ...                                 ...           ...
# 169904      0.173000              ['DripReport', 'Tyga']         0.875
# 169905      0.016700  ['Leon Bridges', 'Terrace Martin']         0.719
# 169906      0.538000               ['Kygo', 'Oh Wonder']         0.514
# 169907      0.071400       ['Cash Cash', 'Andy Grammer']         0.646
# 169908      0.109000                  ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# ...

# %%
ten_df.drop(['explicit', 'mode'], axis=1, inplace=False)
# Out:
#         acousticness                             artists  danceability  \
# 7054        0.022200                     ['Tame Impala']         0.450
# 7055        0.000103            ['Bring Me The Horizon']         0.382
# 7056        0.852000                       ['Daft Punk']         0.179
# 7057        0.080900                         ['TobyMac']         0.507
# 7058        0.002960                   ['Kenny Chesney']         0.315
# ...              ...                                 ...           ...
# 169904      0.173000              ['DripReport', 'Tyga']         0.875
# 169905      0.016700  ['Leon Bridges', 'Terrace Martin']         0.719
# 169906      0.538000               ['Kygo', 'Oh Wonder']         0.514
# 169907      0.071400       ['Cash Cash', 'Andy Grammer']         0.646
# 169908      0.109000                  ['Ingrid Andress']         0.512
#
#         duration_ms  energy                      id  instrumentalness  key  \
# ...

# %%
ten_df.to_csv("tenyear", index=True)
